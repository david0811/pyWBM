# %%
import numpy as np
import pandas as pd
import jax
import jax.numpy as jnp
import optax

from jax import random

key = random.PRNGKey(0)

import matplotlib.pyplot as plt

# %%
inputs = np.load("./data/inputs.npz")

# %%
plt.imshow(inputs["tas"][:, :, 0])
